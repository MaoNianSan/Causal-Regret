# %% [markdown]
# # Experiment 1 Controlled Identifiability Simulation
#
# 本 notebook 只用于 GitHub 可视化展示。原有代码文件未改动；图表和表格均引用项目内已有输出文件。

# %% [markdown]
# ## 图表预览
#
# 以下图片来自 `outputs/figures/`，GitHub 打开 notebook 时可直接预览。

# %% [markdown]
# ### appendix_distortion_diagnostics.png
#
# ![appendix_distortion_diagnostics.png](outputs/figures/appendix_distortion_diagnostics.png)

# %% [markdown]
# ### appendix_full_trajectories.png
#
# ![appendix_full_trajectories.png](outputs/figures/appendix_full_trajectories.png)

# %% [markdown]
# ### appendix_strong_baseline_comparison.png
#
# ![appendix_strong_baseline_comparison.png](outputs/figures/appendix_strong_baseline_comparison.png)

# %% [markdown]
# ### appendix_zero_delay_sanity.png
#
# ![appendix_zero_delay_sanity.png](outputs/figures/appendix_zero_delay_sanity.png)

# %% [markdown]
# ### figure1_regret_trajectory.png
#
# ![figure1_regret_trajectory.png](outputs/figures/figure1_regret_trajectory.png)

# %% [markdown]
# ### figure2_reward_over_time.png
#
# ![figure2_reward_over_time.png](outputs/figures/figure2_reward_over_time.png)

# %% [markdown]
# ### figure3_method_comparison.png
#
# ![figure3_method_comparison.png](outputs/figures/figure3_method_comparison.png)

# %% [markdown]
# ### figure4_action_stability.png
#
# ![figure4_action_stability.png](outputs/figures/figure4_action_stability.png)

# %% [markdown]
# ### figure5_matched_mean_delay_regret.png
#
# ![figure5_matched_mean_delay_regret.png](outputs/figures/figure5_matched_mean_delay_regret.png)

# %% [markdown]
# ## 数据/表格文件索引
# - [`outputs/figures/appendix_proxy_state_error_data.csv`](outputs/figures/appendix_proxy_state_error_data.csv)
# - [`outputs/figures/appendix_ranking_reversal_data.csv`](outputs/figures/appendix_ranking_reversal_data.csv)
# - [`outputs/figures/appendix_source_state_mismatch_data.csv`](outputs/figures/appendix_source_state_mismatch_data.csv)
# - [`outputs/figures/appendix_strong_baseline_comparison.csv`](outputs/figures/appendix_strong_baseline_comparison.csv)
# - [`outputs/figures/appendix_zero_delay_sanity.csv`](outputs/figures/appendix_zero_delay_sanity.csv)
# - [`outputs/figures/figure1_regret_trajectory.csv`](outputs/figures/figure1_regret_trajectory.csv)
# - [`outputs/figures/figure2_reward_over_time.csv`](outputs/figures/figure2_reward_over_time.csv)
# - [`outputs/figures/figure3_method_comparison.csv`](outputs/figures/figure3_method_comparison.csv)
# - [`outputs/figures/figure4_action_stability.csv`](outputs/figures/figure4_action_stability.csv)
# - [`outputs/figures/figure5_matched_mean_delay_regret.csv`](outputs/figures/figure5_matched_mean_delay_regret.csv)
# - [`outputs/summary/action_stability_summary.csv`](outputs/summary/action_stability_summary.csv)
# - [`outputs/summary/bootstrap_ci.csv`](outputs/summary/bootstrap_ci.csv)
# - [`outputs/summary/diagnostic_summary.csv`](outputs/summary/diagnostic_summary.csv)
# - [`outputs/summary/matched_mean_delay_summary.csv`](outputs/summary/matched_mean_delay_summary.csv)
# - [`outputs/summary/method_comparison_summary.csv`](outputs/summary/method_comparison_summary.csv)
# - [`outputs/summary/method_summary.csv`](outputs/summary/method_summary.csv)
# - [`outputs/summary/paired_tests.csv`](outputs/summary/paired_tests.csv)
# - [`outputs/summary/reward_trajectory_summary.csv`](outputs/summary/reward_trajectory_summary.csv)
# - [`outputs/summary/seed_summary.csv`](outputs/summary/seed_summary.csv)
# - [`outputs/summary/trajectory_summary.csv`](outputs/summary/trajectory_summary.csv)
# - [`outputs/worker_return_check.csv`](outputs/worker_return_check.csv)

# %% [markdown]
# ## PDF 图表/报告索引
# - [`outputs/figures/appendix_distortion_diagnostics.pdf`](outputs/figures/appendix_distortion_diagnostics.pdf)
# - [`outputs/figures/appendix_full_trajectories.pdf`](outputs/figures/appendix_full_trajectories.pdf)
# - [`outputs/figures/appendix_strong_baseline_comparison.pdf`](outputs/figures/appendix_strong_baseline_comparison.pdf)
# - [`outputs/figures/appendix_zero_delay_sanity.pdf`](outputs/figures/appendix_zero_delay_sanity.pdf)
# - [`outputs/figures/figure1_regret_trajectory.pdf`](outputs/figures/figure1_regret_trajectory.pdf)
# - [`outputs/figures/figure2_reward_over_time.pdf`](outputs/figures/figure2_reward_over_time.pdf)
# - [`outputs/figures/figure3_method_comparison.pdf`](outputs/figures/figure3_method_comparison.pdf)
# - [`outputs/figures/figure4_action_stability.pdf`](outputs/figures/figure4_action_stability.pdf)
# - [`outputs/figures/figure5_matched_mean_delay_regret.pdf`](outputs/figures/figure5_matched_mean_delay_regret.pdf)

# %% [markdown]
# ## 说明文档索引
# - [`README.md`](README.md)
# - [`output_manifest.md`](output_manifest.md)

# %% [markdown]
# ## 本地可选运行
#
# GitHub 不会自动执行代码。下载后如需重新生成结果，可在项目根目录按需运行：
# - `python main.py`
# - `python reproduce_fast.py`
# - `python reproduce_paper.py`
# - `python plot.py`
# - `python code_check.py`

# %%
from pathlib import Path
root = Path.cwd()
print('当前目录:', root)
print('PNG 图表数量:', len(list(root.glob('outputs/figures/*.png'))))
print('CSV 文件数量:', len(list(root.rglob('*.csv'))))
# Out:
# 当前目录: d:\research\CausalRegretMinimizationUnderDelayedFeedback\experiment\IPY\github\exp1_controlled_identifiability
# PNG 图表数量: 0
# CSV 文件数量: 55
